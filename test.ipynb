# %%
# %load_ext autoreload
# %autoreload 2
import yfinance as yf
import pandas as pd
import numpy as np

# %%
from backtest.dataModule import DataSource, DataModule

# %%
dataSource = DataSource("yfinance", "historical", ["MSFT", "AAPL", "NVDA"])
dataModule = DataModule(dataSource)

# %%
yf.Ticker('MSFT').history()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-08-26 00:00:00-04:00  487.850006  497.399994  487.309998  496.369995
# 2026-08-27 00:00:00-04:00  494.880005  506.480011  490.079987  505.059998
# 2026-08-28 00:00:00-04:00  505.329987  517.780029  504.869995  513.530029
# 2026-08-31 00:00:00-04:00  510.380005  512.190002  506.390015  507.290009
# 2026-09-01 00:00:00-04:00  497.519989  505.970001  496.779999  501.019989
# 2026-09-02 00:00:00-04:00  499.850006  500.269989  493.809998  496.820007
# 2026-09-03 00:00:00-04:00  501.660004  515.650024  500.799988  510.119995
# 2026-09-04 00:00:00-04:00  510.000000  511.000000  499.359985  499.700012
# 2026-09-08 00:00:00-04:00  493.010010  495.190002  490.149994  493.950012
# 2026-09-09 00:00:00-04:00  493.070007  494.390015  489.799988  491.649994
# 2026-09-10 00:00:00-04:00  488.320007  494.519989  486.000000  492.440002
# 2026-09-11 00:00:00-04:00  495.649994  498.970001  492.579987  495.630005
# ...

# %%
test_df = dataModule.load("2020-01-01", "2022-12-31", "1d")
# Out:
# Fetching yfinance price data
# /Users/main/Desktop/python-quant/backtest/dataModule.py:34: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(tickers=self.dataSource.yfTickers,
# [*********************100%***********************]  3 of 3 completed

# %%
test_df
# Out:
#                         close        high         low        open     volume
# date       ticker
# 2020-01-02 AAPL     72.271538   72.331694   71.029915   71.282568  135480400
#            MSFT    151.544281  151.648066  149.383682  149.808252   22622100
#            NVDA      5.957137    5.957137    5.877927    5.928333  237536000
# 2020-01-03 AAPL     71.568932   72.326897   71.345153   71.501557  146322800
#            MSFT    149.657272  150.912123  149.128917  149.374235   21116200
# ...                       ...         ...         ...         ...        ...
# 2022-12-29 MSFT    233.898361  234.781513  228.696522  228.696522   19770700
#            NVDA     14.554338   14.634072   14.179592   14.354009  354923000
# 2022-12-30 AAPL    127.651535  127.671189  125.195383  126.158201   77034200
#            MSFT    232.743484  232.879353  229.676725  231.180991   21938500
#            NVDA     14.565303   14.580252   14.185572   14.286235  310490000
#
# [2268 rows x 5 columns]

# %%
dat = yf.Ticker("MSFT")

# %%
data = yf.download(["MSFT", "NVDA"])
# Out:
# /var/folders/g0/24qwcrld4nb_zw_4mfnl5n240000gn/T/ipykernel_80324/1174321684.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(["MSFT", "NVDA"])
# [*********************100%***********************]  2 of 2 completed

# %%
data
# Out:
# Price            Close                    High                     Low  \
# Ticker            MSFT        NVDA        MSFT        NVDA        MSFT
# Date
# 2026-08-26  496.369995  209.425659  497.399994  213.361258  487.309998
# 2026-08-27  505.059998  227.725174  506.480011  230.212396  490.079987
# 2026-08-28  513.530029  217.306839  517.780029  229.003742  504.869995
# 2026-08-31  507.290009  220.533234  512.190002  221.052657  506.390015
# 2026-09-01  501.019989  217.196976  505.970001  220.163657  496.779999
# 2026-09-02  496.820007  224.159180  500.269989  227.695216  493.809998
# 2026-09-03  510.119995  228.194656  515.650024  230.142474  500.799988
# 2026-09-04  499.700012  230.102524  511.000000  234.497600  499.359985
# 2026-09-08  493.950012  225.477692  495.190002  233.448783  490.149994
# 2026-09-09  491.649994  223.419998  494.390015  225.927187  489.799988
# 2026-09-10  492.440002  218.360001  494.519989  220.990005  486.000000
# ...

# %%
data = data.stack(future_stack=True)

# %%
data.index.names = ['date', 'ticker']
data
# Out:
# Price                   Close        High         Low        Open     Volume
# date       ticker
# 2026-08-26 MSFT    496.369995  497.399994  487.309998  487.850006   20758900
#            NVDA    209.425659  213.361258  208.996132  212.402324  179900000
# 2026-08-27 MSFT    505.059998  506.480011  490.079987  494.880005   28688800
#            NVDA    227.725174  230.212396  220.653086  222.610902  298909800
# 2026-08-28 MSFT    513.530029  517.780029  504.869995  505.329987   29207300
#            NVDA    217.306839  229.003742  216.567661  227.105872  195116400
# 2026-08-31 MSFT    507.290009  512.190002  506.390015  510.380005   27208900
#            NVDA    220.533234  221.052657  215.968349  218.625365  124702700
# 2026-09-01 MSFT    501.019989  505.970001  496.779999  497.519989   21046900
#            NVDA    217.196976  220.163657  214.859595  216.507744  109756200
# 2026-09-02 MSFT    496.820007  500.269989  493.809998  499.850006   15336100
# ...

# %%
data.columns = [col.lower().replace(' ', '_') for col in data.columns]

# %%
data
# Out:
#                         close        high         low        open     volume
# date       ticker
# 2026-08-26 MSFT    496.369995  497.399994  487.309998  487.850006   20758900
#            NVDA    209.425659  213.361258  208.996132  212.402324  179900000
# 2026-08-27 MSFT    505.059998  506.480011  490.079987  494.880005   28688800
#            NVDA    227.725174  230.212396  220.653086  222.610902  298909800
# 2026-08-28 MSFT    513.530029  517.780029  504.869995  505.329987   29207300
#            NVDA    217.306839  229.003742  216.567661  227.105872  195116400
# 2026-08-31 MSFT    507.290009  512.190002  506.390015  510.380005   27208900
#            NVDA    220.533234  221.052657  215.968349  218.625365  124702700
# 2026-09-01 MSFT    501.019989  505.970001  496.779999  497.519989   21046900
#            NVDA    217.196976  220.163657  214.859595  216.507744  109756200
# 2026-09-02 MSFT    496.820007  500.269989  493.809998  499.850006   15336100
# ...

# %%
data
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2026-08-26  496.369995  497.399994  487.309998  487.850006  20758900
# 2026-08-27  505.059998  506.480011  490.079987  494.880005  28688800
# 2026-08-28  513.530029  517.780029  504.869995  505.329987  29207300
# 2026-08-31  507.290009  512.190002  506.390015  510.380005  27208900
# 2026-09-01  501.019989  505.970001  496.779999  497.519989  21046900
# 2026-09-02  496.820007  500.269989  493.809998  499.850006  15336100
# 2026-09-03  510.119995  515.650024  500.799988  501.660004  24125900
# 2026-09-04  499.700012  511.000000  499.359985  510.000000  18101800
# 2026-09-08  493.950012  495.190002  490.149994  493.010010  18882300
# 2026-09-09  491.649994  494.390015  489.799988  493.070007  12889600
# 2026-09-10  492.440002  494.519989  486.000000  488.320007  16038800
# ...
